# %% [markdown]
# # AI Dev dataset

# %%
import pandas as pd
all_pr_df = pd.read_parquet("hf://datasets/hao-li/AIDev/all_pull_request.parquet")
all_repo_df = pd.read_parquet("hf://datasets/hao-li/AIDev/all_repository.parquet")
all_user_df = pd.read_parquet("hf://datasets/hao-li/AIDev/all_user.parquet")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
all_pr_df
# Out:
#                 id  number                                              title  \
# 0       3264016139    1688  `metta code` --> `metta clip` and additional p...
# 1       3264021033      41  feat: Comprehensive ruff error resolution with...
# 2       3264042289    1600  Add Evals frontend implementation plan and HTM...
# 3       3264042318    1601  Add 4 new BfDs components for Evals interface ...
# 4       3264067496       3  🚀 Complete Frontend-Backend API Integration wi...
# ...            ...     ...                                                ...
# 932786  2858495710      79        chore: update RPC endpoint and build target
# 932787  2858498986       6  feat: enhance recruitment management system wi...
# 932788  2858525953      80  fix: revert to PR #73 OpenAI config with updat...
# 932789  2858527610     400          Add Doxygen Documentation for Public APIs
# 932790  2858539698       2   Convert remaining JavaScript files to ES modules
#
#                                                      body        agent  \
# 0       Remove unused `root_key` variable to fix ruff ...  Claude_Code
# 1       ## 🎯 Mission Accomplished: 100% Ruff Error Res...  Claude_Code
# 2       \nCreate comprehensive implementation plan for...  Claude_Code
# 3       \nPhase 1 component creation for the Evals fro...  Claude_Code
# 4       ## 🎯 Summary\n\nThis PR completes the **fronte...  Claude_Code
# ...                                                   ...          ...
# 932786  # Update RPC Endpoint and Build Target\n\nUpda...        Devin
# 932787  # Enhanced Recruitment Management System\n\nTh...        Devin
# 932788  # Revert to PR #73 with Updated RPC Endpoint\n...        Devin
# 932789  # Add Doxygen Documentation for Public APIs\n\...        Devin
# 932790  # Convert remaining JavaScript files to ES mod...        Devin
#
#           user_id                       user   state            created_at  \
# 0           37011              jacklionheart  closed  2025-07-25T18:15:36Z
# 1       131842369                  Draco3310    open  2025-07-25T18:17:57Z
# 2         6766889                  justicart  closed  2025-07-25T18:26:15Z
# 3         6766889                  justicart  closed  2025-07-25T18:26:16Z
# 4        42357482                  twitchyvr  closed  2025-07-25T18:39:14Z
# ...           ...                        ...     ...                   ...
# 932786  158243242  devin-ai-integration[bot]  closed  2025-02-17T17:53:32Z
# 932787  158243242  devin-ai-integration[bot]  closed  2025-02-17T17:55:34Z
# 932788  158243242  devin-ai-integration[bot]  closed  2025-02-17T18:10:27Z
# 932789  158243242  devin-ai-integration[bot]  closed  2025-02-17T18:11:27Z
# 932790  158243242  devin-ai-integration[bot]  closed  2025-02-17T18:18:45Z
#
#                    closed_at             merged_at       repo_id  \
# 0       2025-07-25T19:17:23Z  2025-07-25T19:17:23Z  8.439884e+08
# 1                       None                  None  9.920635e+08
# 2       2025-07-25T23:19:14Z                  None  9.267118e+08
# 3       2025-07-25T23:19:11Z                  None  9.267118e+08
# 4       2025-07-25T18:48:47Z  2025-07-25T18:48:47Z  1.025871e+09
# ...                      ...                   ...           ...
# 932786  2025-02-17T17:54:19Z  2025-02-17T17:54:19Z  9.274854e+08
# 932787  2025-02-18T02:19:26Z  2025-02-18T02:19:26Z  9.334548e+08
# 932788  2025-02-17T18:13:05Z  2025-02-17T18:13:05Z  9.274854e+08
# 932789  2025-02-22T01:15:27Z                  None  1.195796e+08
# 932790  2025-02-18T00:30:37Z  2025-02-18T00:30:37Z  9.339834e+08
#
#                                                  repo_url  \
# 0             https://api.github.com/repos/Metta-AI/metta
# 1       https://api.github.com/repos/Draco3310/Gal-Fri...
# 2       https://api.github.com/repos/bolt-foundry/bolt...
# 3       https://api.github.com/repos/bolt-foundry/bolt...
# 4        https://api.github.com/repos/twitchyvr/Spaghetti
# ...                                                   ...
# 932786    https://api.github.com/repos/xiayuhkust/TuraWAP
# 932787  https://api.github.com/repos/crb12546/musical-...
# 932788    https://api.github.com/repos/xiayuhkust/TuraWAP
# 932789       https://api.github.com/repos/wolfSSL/wolfTPM
# 932790     https://api.github.com/repos/shixin-guo/boostr
#
#                                                  html_url
# 0             https://github.com/Metta-AI/metta/pull/1688
# 1        https://github.com/Draco3310/Gal-Friday2/pull/41
# 2       https://github.com/bolt-foundry/bolt-foundry/p...
# 3       https://github.com/bolt-foundry/bolt-foundry/p...
# 4           https://github.com/twitchyvr/Spaghetti/pull/3
# ...                                                   ...
# 932786      https://github.com/xiayuhkust/TuraWAP/pull/79
# 932787  https://github.com/crb12546/musical-memory/pull/6
# 932788      https://github.com/xiayuhkust/TuraWAP/pull/80
# 932789        https://github.com/wolfSSL/wolfTPM/pull/400
# 932790        https://github.com/shixin-guo/boostr/pull/2
#
# [932791 rows x 14 columns]

# %%
all_repo_df
# Out:
#                 id                                                url  \
# 0        987641962  https://api.github.com/repos/1010-dev/senjudev...
# 1        990249393  https://api.github.com/repos/106-/HellSinkerWa...
# 2       1009549206  https://api.github.com/repos/1genadam/tileshop...
# 3        983546765  https://api.github.com/repos/1kimnet/ETL-pipeline
# 4       1024190983  https://api.github.com/repos/20m61/lightningta...
# ...            ...                                                ...
# 116206  1020305485  https://api.github.com/repos/zx8086/kong-konne...
# 116207   976509925  https://api.github.com/repos/zx8086/mcp-server...
# 116208   989288917  https://api.github.com/repos/zx8086/mcp-server...
# 116209   915873255        https://api.github.com/repos/zxcpluto/First
# 116210  1000819309  https://api.github.com/repos/zyumax/devin-hand...
#
#            license                        full_name    language  forks  stars
# 0             None           1010-dev/senjudev-site  TypeScript    1.0    0.0
# 1             None         106-/HellSinkerWallPaper        Java    0.0    0.0
# 2             None            1genadam/tileshop-rag      Python    0.0    0.0
# 3             None             1kimnet/ETL-pipeline      Python    0.0    0.0
# 4             None       20m61/lightningtalk-circle  JavaScript    0.0    0.0
# ...            ...                              ...         ...    ...    ...
# 116206        None          zx8086/kong-konnect-app      Svelte    0.0    0.0
# 116207        None      zx8086/mcp-server-couchbase  TypeScript    0.0    0.0
# 116208  Apache-2.0  zx8086/mcp-server-elasticsearch  TypeScript    0.0    0.0
# 116209        None                   zxcpluto/First        None    0.0    0.0
# 116210        None            zyumax/devin-hands-on  JavaScript    0.0    0.0
#
# [116211 rows x 7 columns]

# %%
all_user_df
# Out:
#                 id          login  followers  following            created_at
# 0      149159513.0     00012122Cs        0.0        0.0  2023-10-27T10:22:50Z
# 1       86906973.0     000Sean000        0.0        2.0  2021-07-04T07:05:40Z
# 2       36679210.0        000alen       46.0      106.0  2018-02-20T21:00:55Z
# 3      201261210.0       000qhrey        0.0        1.0  2025-02-28T16:53:21Z
# 4       22735204.0       00125495        0.0        1.0  2016-10-10T01:24:34Z
# ...            ...            ...        ...        ...                   ...
# 72184  128873850.0       zztime04        0.0        1.0  2023-03-25T01:50:00Z
# 72185   46803451.0  zzy1099207684        0.0        1.0  2019-01-18T02:51:48Z
# 72186   35818234.0      zzzpotato        2.0        0.0  2018-01-25T20:59:53Z
# 72187   55004427.0        zzzsaft        1.0        0.0  2019-09-06T21:50:29Z
# 72188   46273764.0        zzzz465       42.0       71.0  2018-12-31T04:08:21Z
#
# [72189 rows x 5 columns]

# %%
# Only list users having more than 100 follows in all_user_df
all_user_more_100_df = all_user_df[all_user_df['following'] > 100].sort_values(by='following', ascending=False)
all_user_more_100_df
# Out:
#                 id               login  followers  following  \
# 55766    6391776.0      nikitavoloboev     4857.0    16742.0
# 25343  102006756.0           ZigaoWang     1340.0    15140.0
# 57236   12672027.0          owenlamont      351.0    13886.0
# 11346     178424.0       JeffCarpenter      369.0    11633.0
# 53170    1325144.0        mikedemarais     1741.0     9583.0
# ...            ...                 ...        ...        ...
# 36843    1858708.0              drugoi       86.0      101.0
# 59463   17099856.0  rafaelrojasmiliani       35.0      101.0
# 68728    6257997.0              vdubya       23.0      101.0
# 70680    1251311.0               xywei       46.0      101.0
# 72150   97125186.0             zyang91        6.0      101.0
#
#                  created_at
# 55766  2014-01-13T17:30:13Z
# 25343  2022-03-21T03:01:30Z
# 57236  2015-05-30T11:51:27Z
# 11346  2010-01-08T08:54:08Z
# 53170  2012-01-12T16:05:15Z
# ...                     ...
# 36843  2012-06-17T11:08:34Z
# 59463  2016-02-06T16:54:25Z
# 68728  2013-12-25T07:38:04Z
# 70680  2011-12-09T03:08:04Z
# 72150  2022-01-04T19:14:25Z
#
# [1384 rows x 5 columns]

# %%
# only list pr committed by OpenAI_Codex
all_pr_by_codex_df = all_pr_df[all_pr_df['agent'] == 'OpenAI_Codex']
all_pr_by_codex_df.head(10)
# Out:
#                id  number                                       title  \
# 55584  3122393615      45               Improve FICA estimate helpers
# 55585  3122395724      55      Add message deletion and read receipts
# 55586  3122408581      20  Fix cdscli to persist CDS and zone updates
# 55587  3122417785      79                  Use shared RabbitMQ client
# 55588  3122418753     125                        Split large css file
# 55589  3122420688      24        Fix duplicate tower removal function
# 55590  3122424442      36             Improve interval cleanup in App
# 55591  3122425258      25                  Fix flutter analyze issues
# 55592  3122426013     113             Fix EMG overflow with scipy PDF
# 55593  3122430562       5                    Clean up duplicate files
#
#                                                     body         agent  \
# 55584  ## Summary\n- refine FICA helper functions\n- ...  OpenAI_Codex
# 55585  ## Summary\r\n- refine chat UI with read recei...  OpenAI_Codex
# 55586  ## Summary\n- write CDS files and update zones...  OpenAI_Codex
# 55587  ## Summary\n- expose RabbitMQ service from sha...  OpenAI_Codex
# 55588  ## Summary\n- divide the huge `style.css` into...  OpenAI_Codex
# 55589  ## Summary\n- remove redundant `removeIncorrec...  OpenAI_Codex
# 55590  ## Summary\n- manage interval ID via `useRef`\...  OpenAI_Codex
# 55591  ## Summary\n- prefer final for unchanging fiel...  OpenAI_Codex
# 55592  ## Summary\n- improve stability of `emg_left` ...  OpenAI_Codex
# 55593  ## Summary\n- remove extraneous spreadsheet fi...  OpenAI_Codex
#
#          user_id              user   state            created_at  \
# 55584  130411308         mattb3113  closed  2025-06-05T19:28:33Z
# 55585   84555510          AusBoone  closed  2025-06-05T19:29:23Z
# 55586   23141173            jgwill  closed  2025-06-05T19:33:22Z
# 55587   88899913  Mohammedareebali  closed  2025-06-05T19:36:58Z
# 55588   98446918         rdwr-taly  closed  2025-06-05T19:37:20Z
# 55589    5239796           yannage  closed  2025-06-05T19:38:07Z
# 55590  130038870        jasonlryan  closed  2025-06-05T19:39:25Z
# 55591  214921637          ClubBoss  closed  2025-06-05T19:39:50Z
# 55592   43553722     keeganpaleshi  closed  2025-06-05T19:40:05Z
# 55593   82644920     prabalkaushik  closed  2025-06-05T19:41:49Z
#
#                   closed_at             merged_at      repo_id  \
# 55584  2025-06-05T19:29:00Z  2025-06-05T19:29:00Z  996823776.0
# 55585  2025-06-05T19:29:45Z  2025-06-05T19:29:44Z  633640641.0
# 55586  2025-06-05T20:17:57Z  2025-06-05T20:17:57Z  569242530.0
# 55587  2025-06-05T19:37:28Z  2025-06-05T19:37:28Z  996361900.0
# 55588  2025-06-05T19:37:42Z  2025-06-05T19:37:42Z  983675963.0
# 55589  2025-06-05T19:39:21Z  2025-06-05T19:39:21Z  954628547.0
# 55590  2025-06-05T20:54:41Z  2025-06-05T20:54:41Z  991966565.0
# 55591  2025-06-05T19:40:00Z  2025-06-05T19:40:00Z  996455123.0
# 55592  2025-06-05T19:45:05Z  2025-06-05T19:45:05Z  995736506.0
# 55593  2025-06-05T19:42:16Z  2025-06-05T19:42:16Z  659416692.0
#
#                                                 repo_url  \
# 55584        https://api.github.com/repos/mattb3113/docs
# 55585  https://api.github.com/repos/AusBoone/PrivateLine
# 55586          https://api.github.com/repos/jgwill/jgtpy
# 55587  https://api.github.com/repos/Mohammedareebali/...
# 55588  https://api.github.com/repos/Radware/radware-v...
# 55589  https://api.github.com/repos/yannage/Sudoku-De...
# 55590  https://api.github.com/repos/jasonlryan/hyatt-...
# 55591  https://api.github.com/repos/ClubBoss/Poker_An...
# 55592  https://api.github.com/repos/keeganpaleshi/RMTest
# 55593  https://api.github.com/repos/prabalkaushik/Sen...
#
#                                                 html_url
# 55584          https://github.com/mattb3113/docs/pull/45
# 55585    https://github.com/AusBoone/PrivateLine/pull/55
# 55586            https://github.com/jgwill/jgtpy/pull/20
# 55587   https://github.com/Mohammedareebali/send/pull/79
# 55588  https://github.com/Radware/radware-vulnerable-...
# 55589  https://github.com/yannage/Sudoku-Defense/pull/24
# 55590   https://github.com/jasonlryan/hyatt-demo/pull/36
# 55591  https://github.com/ClubBoss/Poker_Analyzer/pul...
# 55592   https://github.com/keeganpaleshi/RMTest/pull/113
# 55593  https://github.com/prabalkaushik/Sentiment-Ana...

# %% [markdown]
# # AIDev-pop (more than 100 stars)

# %%
# Basic
pr_df = pd.read_parquet("hf://datasets/hao-li/AIDev/pull_request.parquet")
repo_df = pd.read_parquet("hf://datasets/hao-li/AIDev/repository.parquet")
user_df = pd.read_parquet("hf://datasets/hao-li/AIDev/user.parquet")

# Comments and reviews
pr_comments_df = pd.read_parquet("hf://datasets/hao-li/AIDev/pr_comments.parquet")
pr_reviews_df = pd.read_parquet("hf://datasets/hao-li/AIDev/pr_reviews.parquet")
pr_review_comments_df = pd.read_parquet("hf://datasets/hao-li/AIDev/pr_review_comments_v2.parquet")

# Commits
pr_commits_df = pd.read_parquet("hf://datasets/hao-li/AIDev/pr_commits.parquet")
pr_commit_details_df = pd.read_parquet("hf://datasets/hao-li/AIDev/pr_commit_details.parquet")

# Related issues
related_issue_df = pd.read_parquet("hf://datasets/hao-li/AIDev/related_issue.parquet")
issue_df = pd.read_parquet("hf://datasets/hao-li/AIDev/issue.parquet")

# Events
pr_timeline_df = pd.read_parquet("hf://datasets/hao-li/AIDev/pr_timeline.parquet")

# Task type
pr_task_type_df = pd.read_parquet("hf://datasets/hao-li/AIDev/pr_task_type.parquet")

# Human-PR
human_pr_df = pd.read_parquet("hf://datasets/hao-li/AIDev/human_pull_request.parquet")
human_pr_task_type_df = pd.read_parquet("hf://datasets/hao-li/AIDev/human_pr_task_type.parquet")

# %%
print(f"len(pr_df): {len(pr_df)}")
print(f"len(repo_df): {len(repo_df)}")
print(f"len(user_df): {len(user_df)}")

print(f"len(pr_comments_df): {len(pr_comments_df)}")
print(f"len(pr_reviews_df): {len(pr_reviews_df)}")
print(f"len(pr_review_comments_df): {len(pr_review_comments_df)}")

print(f"len(pr_commits_df): {len(pr_commits_df)}")
print(f"len(pr_commit_details_df): {len(pr_commit_details_df)}")


print(f"len(related_issue_df): {len(related_issue_df)}")
print(f"len(issue_df): {len(issue_df)}")

print(f"len(pr_timeline_df): {len(pr_timeline_df)}")

print(f"len(pr_task_type_df): {len(pr_task_type_df)}")

print(f"len(human_pr_df): {len(human_pr_df)}")
print(f"len(human_pr_task_type_df): {len(human_pr_task_type_df)}")
# Out:
# len(pr_df): 33596
# len(repo_df): 2807
# len(user_df): 1796
# len(pr_comments_df): 39122
# len(pr_reviews_df): 28875
# len(pr_review_comments_df): 26868
# len(pr_commits_df): 88576
# len(pr_commit_details_df): 711923
# len(related_issue_df): 4923
# len(issue_df): 4614
# len(pr_timeline_df): 325500
# len(pr_task_type_df): 33596
# len(human_pr_df): 6618
# len(human_pr_task_type_df): 6618

# %%
human_pr_df
# Out:
#               id  number                                              title  \
# 0     2336888723   85268              feat(aci): add automations index page
# 1     2447123365   89131  ref(insights): Make use of `<FeatureBadge>` fo...
# 2     2438086945   88748  :bug: fix: update how we fetch workflow_id and...
# 3     2265431531   83085         fix(org-stats): Require project membership
# 4     2332333882   85102  ref(consumers): Rename parallel -> batched-par...
# ...          ...     ...                                                ...
# 6613  2278132921   32786  Prototype: Enhance Supabase Studio User Impers...
# 6614  2363711435     183                                Update README_CN.md
# 6615  2284333641    1741    [sidecar] get tool use time taken for each node
# 6616  2503287360      89                 perf(copool): remove lock in queue
# 6617  2566240535     331  improvement: Add separate login / signup screens
#
#                 user   user_id   state            created_at  \
# 0          ameliahsu  55610339  closed  2025-02-14T19:04:59Z
# 1            ryan953    187460  closed  2025-04-08T23:29:50Z
# 2        iamrajjoshi  33237075  closed  2025-04-03T21:36:59Z
# 3        ArthurKnaus   7033940  closed  2025-01-08T07:47:13Z
# 4      evanpurkhiser   1421724  closed  2025-02-12T21:24:17Z
# ...              ...       ...     ...                   ...
# 6613     sandengocka  22433712  closed  2025-01-15T01:52:11Z
# 6614        chonchoi   7456582  closed  2025-02-28T04:53:17Z
# 6615         theskcd  10356126  closed  2025-01-17T13:30:40Z
# 6616        noneback  46670806  closed  2025-05-07T05:26:42Z
# 6617  brendan-kellam  10233483  closed  2025-06-04T06:21:57Z
#
#                  closed_at             merged_at  \
# 0     2025-02-18T22:42:20Z  2025-02-18T22:42:19Z
# 1     2025-04-09T15:56:55Z  2025-04-09T15:56:54Z
# 2     2025-04-04T15:10:57Z  2025-04-04T15:10:57Z
# 3     2025-01-08T08:49:40Z  2025-01-08T08:49:40Z
# 4     2025-02-12T22:20:33Z  2025-02-12T22:20:33Z
# ...                    ...                   ...
# 6613  2025-01-22T10:00:59Z  2025-01-22T10:00:59Z
# 6614  2025-02-28T04:59:45Z  2025-02-28T04:59:45Z
# 6615  2025-01-17T13:30:46Z  2025-01-17T13:30:46Z
# 6616  2025-05-07T05:31:00Z  2025-05-07T05:31:00Z
# 6617  2025-06-04T23:42:52Z  2025-06-04T23:42:52Z
#
#                                                repo_url  \
# 0         https://api.github.com/repos/getsentry/sentry
# 1         https://api.github.com/repos/getsentry/sentry
# 2         https://api.github.com/repos/getsentry/sentry
# 3         https://api.github.com/repos/getsentry/sentry
# 4         https://api.github.com/repos/getsentry/sentry
# ...                                                 ...
# 6613     https://api.github.com/repos/supabase/supabase
# 6614     https://api.github.com/repos/PySpur-Dev/pyspur
# 6615   https://api.github.com/repos/codestoryai/sidecar
# 6616  https://api.github.com/repos/noneback/go-taskflow
# 6617  https://api.github.com/repos/sourcebot-dev/sou...
#
#                                                html_url  \
# 0        https://github.com/getsentry/sentry/pull/85268
# 1        https://github.com/getsentry/sentry/pull/89131
# 2        https://github.com/getsentry/sentry/pull/88748
# 3        https://github.com/getsentry/sentry/pull/83085
# 4        https://github.com/getsentry/sentry/pull/85102
# ...                                                 ...
# 6613    https://github.com/supabase/supabase/pull/32786
# 6614      https://github.com/PySpur-Dev/pyspur/pull/183
# 6615   https://github.com/codestoryai/sidecar/pull/1741
# 6616    https://github.com/noneback/go-taskflow/pull/89
# 6617  https://github.com/sourcebot-dev/sourcebot/pul...
#
#                                                    body  agent
# 0     https://sentry-j41gpomr5.sentry.dev/automation...  Human
# 1     Using the premade component reduces an import ...  Human
# 2     i realized i made a mistake for how i fetch th...  Human
# 3     ### Problem\r\n\r\nIf the user is not member o...  Human
# 4     Both crons and uptime consumers have a paralle...  Human
# ...                                                 ...    ...
# 6613  ## I have read the [CONTRIBUTING.md](https://g...  Human
# 6614  Fix translations that are overly "AI-like."\r\...  Human
# 6615                                               None  Human
# 6616                                               None  Human
# 6617  This PR adds a separate signup screen and a sm...  Human
#
# [6618 rows x 13 columns]

# %%
human_pr_task_type_df
# Out:
#       agent          id                                              title  \
# 0     Human  2438086945  :bug: fix: update how we fetch workflow_id and...
# 1     Human  2336888723              feat(aci): add automations index page
# 2     Human  2564963212  feat(insights): update ux for open in explore ...
# 3     Human  2474210990  feat(compare): Add timestamp column to sample ...
# 4     Human  2486573779  ref(perf-issues): Consolidate File IO override...
# ...     ...         ...                                                ...
# 6613  Human  2363711435                                Update README_CN.md
# 6614  Human  2470029531                              Adding zod validation
# 6615  Human  2284333641    [sidecar] get tool use time taken for each node
# 6616  Human  2566240535  improvement: Add separate login / signup screens
# 6617  Human  2278132921  Prototype: Enhance Supabase Studio User Impers...
#
#                                                  reason  type  confidence
# 0     The PR title and description indicate a correc...   fix         NaN
# 1     The title indicates the addition of a new feat...  feat         NaN
# 2     The PR introduces updated user experience (UX)...  feat         NaN
# 3     The PR introduces a new feature by adding a ti...  feat         NaN
# 4     The PR improves the performance issue detectio...  perf         NaN
# ...                                                 ...   ...         ...
# 6613  The changes are focused on improving the trans...  docs         NaN
# 6614  The PR introduces a new feature by adding Zod ...  feat         NaN
# 6615  The PR introduces a new feature to get tool us...  feat         NaN
# 6616  The PR introduces new features including separ...  feat         NaN
# 6617  The PR introduces a new feature that extends S...  feat         NaN
#
# [6618 rows x 6 columns]

# %% [markdown]
# # Extract patches for merged Agentic PRs

# %%
merged_pr_mask = ~pr_df['merged_at'].isna()
merged_pr_ids = pr_df[merged_pr_mask]['id']
patch_mask = pr_commit_details_df['pr_id'].isin(merged_pr_ids)
pr_commit_details_df[patch_mask]['patch'].dropna()
# Out:
# 0         @@ -0,0 +1,38 @@\n+name: Compile llms.txt\n+\n...
# 1         @@ -0,0 +1,47 @@\n+import os\n+from pathlib im...
# 3         @@ -1,47 +1,48 @@\n import os\n from pathlib i...
# 4         @@ -3,45 +3,60 @@\n \n \n def compile_llms_txt...
# 6         @@ -1,29 +1,34 @@\n-import os\n from pathlib i...
#                                 ...
# 711885    @@ -2,6 +2,7 @@\n \n Servers focused on static...
# 711918    @@ -0,0 +1,53 @@\n+# numbagg Development Guide...
# 711919    @@ -49,5 +49,5 @@ uv run pytest numbagg/test/t...
# 711920    @@ -339,7 +339,7 @@\n                         ...
# 711921    @@ -1117,7 +1117,7 @@ export interface ModelHi...
# Name: patch, Length: 402836, dtype: object

# %%
pr_commit_details_df['is_na'] = pr_commit_details_df['patch'].isna()
merged = pd.merge(pr_commit_details_df, all_pr_df[['id', 'agent']], left_on='pr_id', right_on='id')
merged.groupby('agent').apply(lambda x: x['is_na'].value_counts())
# Out:
# /tmp/ipykernel_280/2143530944.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   merged.groupby('agent').apply(lambda x: x['is_na'].value_counts())
# is_na          False  True
# agent
# Claude_Code    20749   2547
# Copilot       154744  32503
# Cursor         35162   2676
# Devin         152064  17403
# OpenAI_Codex  279002  15073

# %% [markdown]
# ### Check PR type

# %%
pr_task_type_df
# Out:
#              agent          id  \
# 0      Claude_Code  3264933329
# 1      Claude_Code  3265709660
# 2      Claude_Code  3265782173
# 3      Claude_Code  3231949586
# 4      Claude_Code  3231950376
# ...            ...         ...
# 33591        Devin  2857168507
# 33592        Devin  2858527610
# 33593        Devin  2858429985
# 33594        Devin  3260345989
# 33595        Devin  3275228771
#
#                                                    title  \
# 0      Fix: Wait for all partitions in load_collectio...
# 1      feat: add comprehensive README screenshots wit...
# 2            chore: remove HashedPostStateProvider trait
# 3      feat(swagger): Add Swagger annotations to Batc...
# 4      feat(swagger): Add Swagger annotations to Batc...
# ...                                                  ...
# 33591                 Add close button to settings modal
# 33592          Add Doxygen Documentation for Public APIs
# 33593         Improve environment variable documentation
# 33594  Match dividend check pattern to invoice requir...
# 33595  Remove line break tags from homepage to fix re...
#
#                                                   reason      type  confidence
# 0               title provides conventional commit label       fix          10
# 1               title provides conventional commit label      feat          10
# 2               title provides conventional commit label     chore          10
# 3               title provides conventional commit label      feat          10
# 4               title provides conventional commit label      feat          10
# ...                                                  ...       ...         ...
# 33591  The commit introduces a new feature by adding ...      feat           9
# 33592  The changes involve adding comprehensive Doxyg...      docs          10
# 33593  The PR focuses on improving and adding documen...      docs          10
# 33594  The change updates the eligibility check logic...  refactor           8
# 33595  The change involves removing <br/> tags to fix...       fix           9
#
# [33596 rows x 6 columns]

# %%
pr_task_type_df['type'].value_counts()
# Out:
# type
# feat        14450
# fix          8106
# docs         3887
# test         2356
# refactor     2288
# chore         896
# build         627
# ci            411
# perf          340
# style         188
# other          31
# revert         16
# Name: count, dtype: int64
